# %%
#14.1 Training a Decision TreeClassiﬁer

# Load libraries
from sklearn.tree import DecisionTreeClassifier
from sklearn import datasets
# Load data
iris=datasets.load_iris()
features=iris.data
target=iris.target
# Create decision tree classifier object
decisiontree=DecisionTreeClassifier(random_state=0)
# Train model
model=decisiontree.fit(features,target)
# Make new observation
observation=[[5,4,3,2]]
# Out:
# array([1])

# %%
# Make new observation
observation=[[5,4,3,2]]
# Predict observation's class
model.predict(observation)
# Out:
# array([1])

# %%
model.predict_proba(observation)
# Out:
# array([[0.028, 0.571, 0.401]])

# %%
# Create decision tree classifier object using entropy
decisiontree_entropy=DecisionTreeClassifier(criterion='entropy',random_state=0)
# Train model
model_entropy=decisiontree_entropy.fit(features,target)

# %%
#14.2 Training a Decision Tree Regressor

# Load libraries
from sklearn.tree import DecisionTreeRegressor
from sklearn import datasets
# Load data with only two features
boston=datasets.load_boston()
features=boston.data[:,0:2]
target=boston.target
# Create decision tree classifier object
decisiontree=DecisionTreeRegressor(random_state=0)
# Train model
model=decisiontree.fit(features,target)
# Out:
# C:\Users\cduy5\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function load_boston is deprecated; `load_boston` is deprecated in 1.0 and will be removed in 1.2.
#
#     The Boston housing prices dataset has an ethical problem. You can refer to
#     the documentation of this function for further details.
#
#     The scikit-learn maintainers therefore strongly discourage the use of this
#     dataset unless the purpose of the code is to study and educate about
#     ethical issues in data science and machine learning.
#
#     In this special case, you can fetch the dataset from the original
#     source::
#
#         import pandas as pd
#         import numpy as np
#
#
#         data_url = "http://lib.stat.cmu.edu/datasets/boston"
#         raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#         data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#         target = raw_df.values[1::2, 2]
#
#     Alternative datasets include the California housing dataset (i.e.
#     :func:`~sklearn.datasets.fetch_california_housing`) and the Ames housing
#     dataset. You can load the datasets as follows::
#
#         from sklearn.datasets import fetch_california_housing
#         housing = fetch_california_housing()
#
#     for the California housing dataset and::
#
#         from sklearn.datasets import fetch_openml
#         housing = fetch_openml(name="house_prices", as_frame=True)
#
#     for the Ames housing dataset.
#
#   warnings.warn(msg, category=FutureWarning)

# %%
# Make new observation
observation=[[0.02,16]]
# Predict observation's value
model.predict(observation)
# Out:
# array([33.])

# %%
# Create decision tree classifier object using entropy
decisiontree_mae=DecisionTreeRegressor(criterion="mae",random_state=0)
# Train model
model_mae=decisiontree_mae.fit(features,target)
# Out:
# C:\Users\cduy5\anaconda3\lib\site-packages\sklearn\tree\_classes.py:366: FutureWarning: Criterion 'mae' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='absolute_error'` which is equivalent.
#   warnings.warn(

# %%
conda install -c conda-forge pydotplus
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\cduy5\anaconda3
#
#   added / updated specs:
#     - pydotplus
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     cairo-1.16.0               |    h63a05c6_1001         5.2 MB  conda-forge
#     conda-23.1.0               |   py39hcbf5309_0         912 KB  conda-forge
#     expat-2.4.9                |       h6c2663c_0         207 KB
#     fribidi-1.0.10             |       h8d14728_0          63 KB  conda-forge
#     getopt-win32-0.1           |       h8ffe710_0          19 KB  conda-forge
#     glib-2.69.1                |       h5dc1a3c_1         1.6 MB
#     graphite2-1.3.14           |       hd77b12b_1          91 KB
#     graphviz-2.50.0            |       hdb8b0d4_0         903 KB
#     gts-0.7.6                  |       h69fa6b1_0         186 KB  conda-forge
#     harfbuzz-4.3.0             |       hb646838_1         855 KB
#     libffi-3.4.2               |       h8ffe710_5          41 KB  conda-forge
#     libgd-2.3.3                |       ha43c60c_1         314 KB
#     pango-1.50.7               |       h78c2152_0         279 KB
#     pcre-8.45                  |       h0e60522_0         518 KB  conda-forge
#     pixman-0.38.0              |    hfa6e2cd_1003         993 KB  conda-forge
#     pydotplus-2.0.2            |     pyhaef67bd_5          24 KB  conda-forge
#     python_abi-3.9             |           2_cp39           4 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        12.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   cairo              conda-forge/win-64::cairo-1.16.0-h63a05c6_1001
#   expat              pkgs/main/win-64::expat-2.4.9-h6c2663c_0
#   fribidi            conda-forge/win-64::fribidi-1.0.10-h8d14728_0
#   getopt-win32       conda-forge/win-64::getopt-win32-0.1-h8ffe710_0
#   glib               pkgs/main/win-64::glib-2.69.1-h5dc1a3c_1
#   graphite2          pkgs/main/win-64::graphite2-1.3.14-hd77b12b_1
#   graphviz           pkgs/main/win-64::graphviz-2.50.0-hdb8b0d4_0
#   gts                conda-forge/win-64::gts-0.7.6-h69fa6b1_0
#   harfbuzz           pkgs/main/win-64::harfbuzz-4.3.0-hb646838_1
#   libffi             conda-forge/win-64::libffi-3.4.2-h8ffe710_5
#   libgd              pkgs/main/win-64::libgd-2.3.3-ha43c60c_1
#   pango              pkgs/main/win-64::pango-1.50.7-h78c2152_0
#   pcre               conda-forge/win-64::pcre-8.45-h0e60522_0
#   pixman             conda-forge/win-64::pixman-0.38.0-hfa6e2cd_1003
#   pydotplus          conda-forge/noarch::pydotplus-2.0.2-pyhaef67bd_5
#   python_abi         conda-forge/win-64::python_abi-3.9-2_cp39
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   conda              pkgs/main::conda-23.1.0-py39haa95532_0 --> conda-forge::conda-23.1.0-py39hcbf5309_0
#
#
#
# Downloading and Extracting Packages
#
# fribidi-1.0.10       | 63 KB     |            |   0%
#
# libffi-3.4.2         | 41 KB     |            |   0%
#
#
# pixman-0.38.0        | 993 KB    |            |   0%
#
#
#
# python_abi-3.9       | 4 KB      |            |   0%
#
#
#
#
# graphite2-1.3.14     | 91 KB     |            |   0%
#
#
#
#
#
# conda-23.1.0         | 912 KB    |            |   0%
#
#
#
#
#
#
# libgd-2.3.3          | 314 KB    |            |   0%
#
#
#
#
#
#
#
# graphviz-2.50.0      | 903 KB    |            |   0%
#
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 855 KB    |            |   0%
#
#
#
#
#
#
#
#
#
# pango-1.50.7         | 279 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
# pcre-8.45            | 518 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
# gts-0.7.6            | 186 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# expat-2.4.9          | 207 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.69.1          | 1.6 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# getopt-win32-0.1     | 19 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pydotplus-2.0.2      | 24 KB     |            |   0%
#
#
#
#
# graphite2-1.3.14     | 91 KB     | #7         |  18%
#
#
#
#
# graphite2-1.3.14     | 91 KB     | ###5       |  35%
#
#
#
#
# graphite2-1.3.14     | 91 KB     | #####2     |  53%
#
#
#
# python_abi-3.9       | 4 KB      | ########## | 100%
#
# libffi-3.4.2         | 41 KB     | ###8       |  39%
#
#
#
# python_abi-3.9       | 4 KB      | ########## | 100%
#
#
# pixman-0.38.0        | 993 KB    | 1          |   2%
#
#
#
#
# graphite2-1.3.14     | 91 KB     | ########8  |  88%
# fribidi-1.0.10       | 63 KB     | ##5        |  25%
#
#
# pixman-0.38.0        | 993 KB    | 3          |   3%
# fribidi-1.0.10       | 63 KB     | #####      |  51%
#
#
# pixman-0.38.0        | 993 KB    | 4          |   5%
#
#
#
#
# graphite2-1.3.14     | 91 KB     | ########## | 100%
#
#
#
#
# graphite2-1.3.14     | 91 KB     | ########## | 100%
#
# libffi-3.4.2         | 41 KB     | ########## | 100%
#
# libffi-3.4.2         | 41 KB     | ########## | 100%
#
#
# pixman-0.38.0        | 993 KB    | 6          |   6%
#
#
#
#
#
# conda-23.1.0         | 912 KB    | 1          |   2%
#
#
# pixman-0.38.0        | 993 KB    | 9          |  10%
# fribidi-1.0.10       | 63 KB     | #######6   |  76%
# fribidi-1.0.10       | 63 KB     | ########## | 100%
#
#
# pixman-0.38.0        | 993 KB    | #1         |  11%
#
#
#
#
#
#
# libgd-2.3.3          | 314 KB    | 5          |   5%
#
#
#
#
#
#
# libgd-2.3.3          | 314 KB    | #5         |  15%
#
#
# pixman-0.38.0        | 993 KB    | #6         |  16%
#
#
# pixman-0.38.0        | 993 KB    | #9         |  19%
#
#
#
#
#
# conda-23.1.0         | 912 KB    | 3          |   4%
#
#
#
#
#
#
# libgd-2.3.3          | 314 KB    | ##5        |  25%
#
#
# pixman-0.38.0        | 993 KB    | ##         |  21%
#
#
#
#
#
#
# libgd-2.3.3          | 314 KB    | ###5       |  36%
#
#
# pixman-0.38.0        | 993 KB    | ##2        |  23%
#
#
#
#
#
# conda-23.1.0         | 912 KB    | 5          |   5%
#
#
#
#
#
#
# libgd-2.3.3          | 314 KB    | ####       |  41%
#
#
# pixman-0.38.0        | 993 KB    | ##4        |  24%
#
#
#
#
#
#
# libgd-2.3.3          | 314 KB    | #####      |  51%
#
#
#
#
#
#
# libgd-2.3.3          | 314 KB    | #####5     |  56%
#
#
# pixman-0.38.0        | 993 KB    | ##5        |  26%
#
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 855 KB    | 1          |   2%
#
#
#
#
#
#
# libgd-2.3.3          | 314 KB    | ######1    |  61%
#
#
# pixman-0.38.0        | 993 KB    | ##7        |  27%
#
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 855 KB    | 5          |   6%
#
#
#
#
#
#
# libgd-2.3.3          | 314 KB    | ######6    |  66%
#
#
#
#
#
# conda-23.1.0         | 912 KB    | 7          |   7%
#
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 855 KB    | 7          |   7%
#
#
#
#
#
#
# libgd-2.3.3          | 314 KB    | #######1   |  71%
#
#
# pixman-0.38.0        | 993 KB    | ##8        |  29%
#
#
#
#
#
#
# libgd-2.3.3          | 314 KB    | #######6   |  76%
#
#
# pixman-0.38.0        | 993 KB    | ###        |  31%
#
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 855 KB    | 9          |   9%
#
#
#
#
#
#
#
# graphviz-2.50.0      | 903 KB    | 1          |   2%
#
#
#
#
#
#
# libgd-2.3.3          | 314 KB    | ########1  |  81%
#
#
# pixman-0.38.0        | 993 KB    | ###2       |  32%
#
#
#
#
#
#
#
# graphviz-2.50.0      | 903 KB    | 5          |   5%
#
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 855 KB    | #3         |  13%
#
#
# pixman-0.38.0        | 993 KB    | ###3       |  34%
#
#
#
#
#
#
#
# graphviz-2.50.0      | 903 KB    | 7          |   7%
#
#
#
#
#
#
# libgd-2.3.3          | 314 KB    | #########1 |  92%
#
#
# pixman-0.38.0        | 993 KB    | ###5       |  35%
#
#
#
#
#
#
# libgd-2.3.3          | 314 KB    | ########## | 100%
#
#
#
#
#
#
# libgd-2.3.3          | 314 KB    | ########## | 100%
#
#
#
#
#
# conda-23.1.0         | 912 KB    | 8          |   9%
#
#
# pixman-0.38.0        | 993 KB    | ###7       |  37%
#
#
#
#
#
#
#
# graphviz-2.50.0      | 903 KB    | 8          |   9%
#
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 855 KB    | #4         |  15%
#
#
#
#
#
# conda-23.1.0         | 912 KB    | #          |  11%
#
#
# pixman-0.38.0        | 993 KB    | ###8       |  39%
#
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 855 KB    | ##4        |  24%
#
#
#
#
#
#
#
# graphviz-2.50.0      | 903 KB    | #          |  11%
#
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 855 KB    | ##8        |  28%
#
#
# pixman-0.38.0        | 993 KB    | ####       |  40%
#
#
#
#
#
#
#
# graphviz-2.50.0      | 903 KB    | #2         |  12%
#
#
# pixman-0.38.0        | 993 KB    | ####1      |  42%
#
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 855 KB    | ###1       |  32%
#
#
#
#
#
#
#
#
#
# pango-1.50.7         | 279 KB    | 5          |   6%
#
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 855 KB    | ###3       |  34%
#
#
#
#
#
#
#
# graphviz-2.50.0      | 903 KB    | #4         |  14%
#
#
#
#
#
# conda-23.1.0         | 912 KB    | #4         |  14%
#
#
# pixman-0.38.0        | 993 KB    | ####3      |  43%
#
#
#
#
#
# conda-23.1.0         | 912 KB    | #5         |  16%
#
#
# pixman-0.38.0        | 993 KB    | ####5      |  45%
#
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 855 KB    | ###5       |  36%
#
#
#
#
#
#
#
# graphviz-2.50.0      | 903 KB    | #5         |  16%
#
#
# pixman-0.38.0        | 993 KB    | ####6      |  47%
#
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 855 KB    | ####3      |  43%
#
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 855 KB    | ####6      |  47%
#
#
# pixman-0.38.0        | 993 KB    | ####8      |  48%
#
#
#
#
#
#
#
#
#
# pango-1.50.7         | 279 KB    | #1         |  11%
#
#
#
#
#
# conda-23.1.0         | 912 KB    | #7         |  18%
#
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 855 KB    | #####      |  51%
#
#
#
#
#
#
#
# graphviz-2.50.0      | 903 KB    | #7         |  18%
#
#
#
#
#
# conda-23.1.0         | 912 KB    | #9         |  19%
#
#
#
#
#
# conda-23.1.0         | 912 KB    | ##1        |  21%
#
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 855 KB    | #####2     |  52%
#
#
# pixman-0.38.0        | 993 KB    | #####1     |  52%
#
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 855 KB    | #####6     |  56%
#
#
# pixman-0.38.0        | 993 KB    | #####4     |  55%
#
#
#
#
#
#
#
# graphviz-2.50.0      | 903 KB    | ##3        |  23%
#
#
#
#
#
#
#
#
#
# pango-1.50.7         | 279 KB    | ###4       |  34%
#
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 855 KB    | ######1    |  62%
#
#
#
#
#
# conda-23.1.0         | 912 KB    | ##2        |  23%
#
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 855 KB    | ######5    |  65%
#
#
#
#
#
#
#
#
#
# pango-1.50.7         | 279 KB    | ####5      |  46%
#
#
#
#
#
#
#
# graphviz-2.50.0      | 903 KB    | ##6        |  27%
#
#
#
#
#
# conda-23.1.0         | 912 KB    | ##4        |  25%
#
#
# pixman-0.38.0        | 993 KB    | #####6     |  56%
#
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 855 KB    | ######7    |  67%
#
#
#
#
#
# conda-23.1.0         | 912 KB    | ##6        |  26%
#
#
#
#
#
#
#
# graphviz-2.50.0      | 903 KB    | ###1       |  32%
#
#
#
#
#
#
#
#
#
# pango-1.50.7         | 279 KB    | #####1     |  52%
#
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 855 KB    | #######1   |  71%
#
#
#
#
#
#
#
# graphviz-2.50.0      | 903 KB    | ###5       |  35%
#
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 855 KB    | #######2   |  73%
#
#
#
#
#
# conda-23.1.0         | 912 KB    | ##8        |  28%
#
#
# pixman-0.38.0        | 993 KB    | ######1    |  61%
#
#
#
#
#
#
#
# graphviz-2.50.0      | 903 KB    | ###7       |  37%
#
#
# pixman-0.38.0        | 993 KB    | ######2    |  63%
#
#
#
#
#
#
#
#
#
# pango-1.50.7         | 279 KB    | ######3    |  63%
#
#
#
#
#
# conda-23.1.0         | 912 KB    | ##9        |  30%
#
#
#
#
#
# conda-23.1.0         | 912 KB    | ###1       |  32%
#
#
#
#
#
# conda-23.1.0         | 912 KB    | ###3       |  33%
#
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 855 KB    | #######4   |  75%
#
#
#
#
#
#
#
# graphviz-2.50.0      | 903 KB    | ###8       |  39%
#
#
#
#
#
#
#
#
#
# pango-1.50.7         | 279 KB    | ######8    |  69%
#
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 855 KB    | #######8   |  79%
#
#
#
#
#
#
#
#
#
# pango-1.50.7         | 279 KB    | #######4   |  75%
#
#
#
#
#
# conda-23.1.0         | 912 KB    | ###5       |  35%
#
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 855 KB    | ########   |  80%
#
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 855 KB    | ########2  |  82%
#
#
#
#
#
#
#
#
#
# pango-1.50.7         | 279 KB    | #########1 |  92%
#
#
#
#
#
# conda-23.1.0         | 912 KB    | ###6       |  37%
#
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 855 KB    | ########9  |  90%
#
#
#
#
#
# conda-23.1.0         | 912 KB    | ###8       |  39%
#
#
#
#
#
#
#
#
#
# pango-1.50.7         | 279 KB    | #########7 |  97%
#
#
#
#
#
#
#
#
#
# pango-1.50.7         | 279 KB    | ########## | 100%
#
#
#
#
#
# conda-23.1.0         | 912 KB    | ####       |  40%
#
#
#
#
#
#
#
# graphviz-2.50.0      | 903 KB    | ####       |  41%
#
#
# pixman-0.38.0        | 993 KB    | ######4    |  64%
#
#
#
#
#
#
#
# graphviz-2.50.0      | 903 KB    | #####4     |  55%
#
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 855 KB    | #########1 |  92%
#
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 855 KB    | #########3 |  94%
#
#
#
#
#
# conda-23.1.0         | 912 KB    | ####2      |  42%
#
#
# pixman-0.38.0        | 993 KB    | #######    |  71%
#
#
#
#
#
#
#
# graphviz-2.50.0      | 903 KB    | #####6     |  57%
#
#
#
#
#
#
#
# graphviz-2.50.0      | 903 KB    | #####8     |  58%
#
#
# pixman-0.38.0        | 993 KB    | #######2   |  72%
#
#
#
#
#
#
#
# graphviz-2.50.0      | 903 KB    | ######     |  60%
#
#
#
#
#
# conda-23.1.0         | 912 KB    | ####3      |  44%
#
#
# pixman-0.38.0        | 993 KB    | #######4   |  74%
#
#
#
#
#
#
#
#
#
#
# pcre-8.45            | 518 KB    | 3          |   3%
#
#
#
#
#
#
#
#
#
#
# pcre-8.45            | 518 KB    | 9          |   9%
#
#
#
#
#
#
#
# graphviz-2.50.0      | 903 KB    | ######2    |  62%
#
#
#
#
#
#
#
#
#
#
# pcre-8.45            | 518 KB    | #5         |  15%
#
#
# pixman-0.38.0        | 993 KB    | #######5   |  76%
#
#
#
#
#
# conda-23.1.0         | 912 KB    | ####5      |  46%
#
#
#
#
#
#
#
# graphviz-2.50.0      | 903 KB    | ######3    |  64%
#
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 855 KB    | #########9 |  99%
#
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 855 KB    | ########## | 100%
#
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 855 KB    | ########## | 100%
#
#
#
#
#
# conda-23.1.0         | 912 KB    | ####7      |  47%
#
#
# pixman-0.38.0        | 993 KB    | #######7   |  77%
#
#
#
#
#
#
#
# graphviz-2.50.0      | 903 KB    | ######5    |  66%
#
#
# pixman-0.38.0        | 993 KB    | #######8   |  79%
#
#
#
#
#
# conda-23.1.0         | 912 KB    | ####9      |  49%
#
#
#
#
#
#
#
#
#
#
# pcre-8.45            | 518 KB    | #8         |  19%
#
#
#
#
#
#
#
#
#
#
# pcre-8.45            | 518 KB    | ####       |  40%
#
#
#
#
#
# conda-23.1.0         | 912 KB    | #####      |  51%
#
#
#
#
#
#
#
# graphviz-2.50.0      | 903 KB    | ######9    |  69%
#
#
#
#
#
#
#
#
#
#
#
# gts-0.7.6            | 186 KB    | 8          |   9%
#
#
#
#
#
#
#
#
#
#
# pcre-8.45            | 518 KB    | ####3      |  43%
#
#
#
#
#
#
#
# graphviz-2.50.0      | 903 KB    | #######9   |  80%
#
#
# pixman-0.38.0        | 993 KB    | ########3  |  84%
#
#
#
#
#
# conda-23.1.0         | 912 KB    | #####2     |  53%
#
#
#
#
#
#
#
# graphviz-2.50.0      | 903 KB    | ########1  |  81%
#
#
#
#
#
#
#
#
#
#
# pcre-8.45            | 518 KB    | ####9      |  49%
#
#
# pixman-0.38.0        | 993 KB    | ########8  |  89%
#
#
#
#
#
#
#
#
#
#
#
# gts-0.7.6            | 186 KB    | #7         |  17%
#
#
#
#
#
#
#
# graphviz-2.50.0      | 903 KB    | ########3  |  83%
#
#
#
#
#
#
#
#
#
#
# pcre-8.45            | 518 KB    | #####2     |  52%
#
#
# pixman-0.38.0        | 993 KB    | #########  |  90%
#
#
#
#
#
# conda-23.1.0         | 912 KB    | #####4     |  54%
#
#
#
#
#
#
#
# graphviz-2.50.0      | 903 KB    | ########5  |  85%
#
#
#
#
#
#
#
#
#
#
# pcre-8.45            | 518 KB    | #####5     |  56%
#
#
# pixman-0.38.0        | 993 KB    | #########1 |  92%
#
#
#
#
#
#
#
#
#
#
# pcre-8.45            | 518 KB    | #####8     |  59%
#
#
#
#
#
#
#
# graphviz-2.50.0      | 903 KB    | ########6  |  87%
#
#
#
#
#
#
#
#
#
#
#
# gts-0.7.6            | 186 KB    | ##5        |  26%
#
#
#
#
#
# conda-23.1.0         | 912 KB    | #####6     |  56%
#
#
#
#
#
#
#
#
#
#
# pcre-8.45            | 518 KB    | ######1    |  62%
#
#
# pixman-0.38.0        | 993 KB    | #########3 |  93%
#
#
#
#
#
#
#
# graphviz-2.50.0      | 903 KB    | ########8  |  89%
#
#
#
#
#
#
#
#
#
#
# pcre-8.45            | 518 KB    | ######4    |  65%
#
#
#
#
#
#
#
#
#
#
#
# gts-0.7.6            | 186 KB    | ###4       |  34%
#
#
# pixman-0.38.0        | 993 KB    | #########5 |  95%
#
#
#
#
#
# conda-23.1.0         | 912 KB    | #####7     |  58%
#
#
#
#
#
#
#
# graphviz-2.50.0      | 903 KB    | #########  |  90%
#
#
#
#
#
#
#
#
#
#
# pcre-8.45            | 518 KB    | ######7    |  68%
#
#
# pixman-0.38.0        | 993 KB    | #########6 |  97%
#
#
#
#
#
#
#
#
#
#
#
# gts-0.7.6            | 186 KB    | ####3      |  43%
#
#
#
#
#
#
#
#
#
#
# pcre-8.45            | 518 KB    | #######    |  71%
#
#
#
#
#
#
#
#
#
#
# pcre-8.45            | 518 KB    | #######4   |  74%
#
#
#
#
#
#
#
# graphviz-2.50.0      | 903 KB    | #########2 |  92%
#
#
#
#
#
# conda-23.1.0         | 912 KB    | #####9     |  60%
#
#
# pixman-0.38.0        | 993 KB    | #########8 |  98%
#
#
#
#
#
#
#
#
#
#
#
# gts-0.7.6            | 186 KB    | #####1     |  52%
#
#
#
#
#
#
#
#
#
#
# pcre-8.45            | 518 KB    | #######7   |  77%
#
#
# pixman-0.38.0        | 993 KB    | #########9 | 100%
#
#
#
#
#
#
#
#
#
#
# pcre-8.45            | 518 KB    | ########   |  80%
#
#
#
#
#
# conda-23.1.0         | 912 KB    | ######1    |  61%
#
#
#
#
#
#
#
#
#
#
#
# gts-0.7.6            | 186 KB    | ######     |  60%
#
#
#
#
#
#
#
#
#
#
# pcre-8.45            | 518 KB    | ########3  |  83%
#
#
#
#
#
#
#
# graphviz-2.50.0      | 903 KB    | #########3 |  94%
#
#
# pixman-0.38.0        | 993 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
# pcre-8.45            | 518 KB    | ########9  |  90%
#
#
#
#
#
#
#
#
#
#
#
# gts-0.7.6            | 186 KB    | ######8    |  69%
#
#
#
#
#
#
#
#
#
#
# pcre-8.45            | 518 KB    | #########2 |  93%
#
#
#
#
#
# conda-23.1.0         | 912 KB    | ######3    |  63%
#
#
#
#
#
#
#
#
#
#
#
# gts-0.7.6            | 186 KB    | #######7   |  77%
#
#
#
#
#
#
#
#
#
#
# pcre-8.45            | 518 KB    | #########5 |  96%
#
#
#
#
#
#
#
# graphviz-2.50.0      | 903 KB    | #########5 |  96%
#
#
#
#
#
#
#
#
#
#
# pcre-8.45            | 518 KB    | #########8 |  99%
#
#
#
#
#
# conda-23.1.0         | 912 KB    | ######4    |  65%
#
#
#
#
#
#
#
# graphviz-2.50.0      | 903 KB    | #########7 |  97%
#
#
#
#
#
#
#
#
#
#
#
# gts-0.7.6            | 186 KB    | ########6  |  86%
#
#
#
#
#
#
#
#
#
#
# pcre-8.45            | 518 KB    | ########## | 100%
#
#
#
#
#
#
#
# graphviz-2.50.0      | 903 KB    | #########9 |  99%
#
#
#
#
#
# conda-23.1.0         | 912 KB    | ######6    |  67%
#
#
#
#
#
#
#
#
#
#
#
# gts-0.7.6            | 186 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    |            |   0%
#
#
#
#
#
#
#
# graphviz-2.50.0      | 903 KB    | ########## | 100%
#
#
#
#
#
#
#
# graphviz-2.50.0      | 903 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
# gts-0.7.6            | 186 KB    | ########## | 100%
#
#
#
#
#
# conda-23.1.0         | 912 KB    | ######8    |  68%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    |            |   1%
#
#
#
#
#
# conda-23.1.0         | 912 KB    | #######    |  70%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | 1          |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# getopt-win32-0.1     | 19 KB     | ########5  |  86%
#
#
#
#
#
# conda-23.1.0         | 912 KB    | #######1   |  72%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# getopt-win32-0.1     | 19 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | 1          |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.69.1          | 1.6 MB    |            |   1%
#
#
#
#
#
# conda-23.1.0         | 912 KB    | #######3   |  74%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | 2          |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
# expat-2.4.9          | 207 KB    | 7          |   8%
#
#
#
#
#
# conda-23.1.0         | 912 KB    | #######5   |  75%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | 2          |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.69.1          | 1.6 MB    | 1          |   2%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | 2          |   3%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pydotplus-2.0.2      | 24 KB     | ######5    |  66%
#
#
#
#
#
# conda-23.1.0         | 912 KB    | #######7   |  77%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.69.1          | 1.6 MB    | 2          |   3%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | 2          |   3%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | 3          |   3%
#
#
#
#
#
#
#
#
#
#
#
#
#
# expat-2.4.9          | 207 KB    | #5         |  15%
#
#
#
#
#
# conda-23.1.0         | 912 KB    | ########   |  81%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.69.1          | 1.6 MB    | 3          |   4%
#
#
#
#
#
# conda-23.1.0         | 912 KB    | ########2  |  82%
#
#
#
#
#
#
#
#
#
#
#
#
#
# expat-2.4.9          | 207 KB    | ###        |  31%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | 4          |   4%
#
#
#
#
#
# conda-23.1.0         | 912 KB    | ########5  |  86%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | 4          |   4%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.69.1          | 1.6 MB    | 5          |   6%
#
#
#
#
#
#
#
#
#
#
#
#
#
# expat-2.4.9          | 207 KB    | ###8       |  39%
#
#
#
#
#
# conda-23.1.0         | 912 KB    | ########7  |  88%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | 4          |   5%
#
#
#
#
#
# conda-23.1.0         | 912 KB    | ########9  |  89%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.69.1          | 1.6 MB    | 6          |   7%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | 5          |   5%
#
#
#
#
#
#
#
#
#
#
#
#
#
# expat-2.4.9          | 207 KB    | ####6      |  46%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pydotplus-2.0.2      | 24 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pydotplus-2.0.2      | 24 KB     | ########## | 100%
#
#
#
#
#
# conda-23.1.0         | 912 KB    | #########1 |  91%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | 5          |   5%
#
#
#
#
#
# conda-23.1.0         | 912 KB    | #########2 |  93%
#
#
#
#
#
# conda-23.1.0         | 912 KB    | #########6 |  96%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.69.1          | 1.6 MB    | 7          |   8%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | 5          |   6%
#
#
#
#
#
#
#
#
#
#
#
#
#
# expat-2.4.9          | 207 KB    | #####4     |  54%
#
#
#
#
#
#
#
#
#
#
#
#
#
# expat-2.4.9          | 207 KB    | ######1    |  62%
#
#
#
#
#
# conda-23.1.0         | 912 KB    | #########8 |  98%
#
#
#
#
#
#
#
#
#
#
#
#
#
# expat-2.4.9          | 207 KB    | ######9    |  70%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.69.1          | 1.6 MB    | 8          |   9%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | 5          |   6%
#
#
#
#
#
# conda-23.1.0         | 912 KB    | ########## | 100%
#
#
#
#
#
# conda-23.1.0         | 912 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.69.1          | 1.6 MB    | #          |  11%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | 7          |   7%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | 7          |   7%
#
#
#
#
#
#
#
#
#
#
#
#
#
# expat-2.4.9          | 207 KB    | #######7   |  77%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.69.1          | 1.6 MB    | #1         |  12%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | 7          |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.69.1          | 1.6 MB    | #3         |  14%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | 8          |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
# expat-2.4.9          | 207 KB    | #########2 |  93%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.69.1          | 1.6 MB    | #4         |  15%
#
#
#
#
#
#
#
#
#
#
#
#
#
# expat-2.4.9          | 207 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | 8          |   9%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.69.1          | 1.6 MB    | #5         |  16%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | 8          |   9%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.69.1          | 1.6 MB    | #6         |  17%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.69.1          | 1.6 MB    | #7         |  18%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.69.1          | 1.6 MB    | #8         |  19%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | 9          |   9%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.69.1          | 1.6 MB    | #9         |  20%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.69.1          | 1.6 MB    | ##         |  21%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.69.1          | 1.6 MB    | ##1        |  22%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.69.1          | 1.6 MB    | ##2        |  23%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.69.1          | 1.6 MB    | ##3        |  24%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.69.1          | 1.6 MB    | ##6        |  27%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | 9          |  10%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.69.1          | 1.6 MB    | ##9        |  30%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.69.1          | 1.6 MB    | ###1       |  32%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.69.1          | 1.6 MB    | ###3       |  34%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.69.1          | 1.6 MB    | ###5       |  36%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.69.1          | 1.6 MB    | ###6       |  37%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.69.1          | 1.6 MB    | ####2      |  43%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | 9          |  10%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.69.1          | 1.6 MB    | ####6      |  47%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.69.1          | 1.6 MB    | ####7      |  48%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.69.1          | 1.6 MB    | #####3     |  53%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.69.1          | 1.6 MB    | #####5     |  55%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.69.1          | 1.6 MB    | #####7     |  57%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.69.1          | 1.6 MB    | #####9     |  59%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #1         |  11%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #1         |  11%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.69.1          | 1.6 MB    | ######1    |  61%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.69.1          | 1.6 MB    | #######6   |  76%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.69.1          | 1.6 MB    | ########   |  80%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #1         |  12%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.69.1          | 1.6 MB    | ########3  |  83%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.69.1          | 1.6 MB    | ########6  |  86%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.69.1          | 1.6 MB    | ########8  |  88%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.69.1          | 1.6 MB    | #########  |  90%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.69.1          | 1.6 MB    | #########2 |  92%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.69.1          | 1.6 MB    | #########4 |  94%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.69.1          | 1.6 MB    | #########6 |  96%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #1         |  12%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.69.1          | 1.6 MB    | #########8 |  98%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #2         |  12%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.69.1          | 1.6 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.69.1          | 1.6 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #2         |  13%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #2         |  13%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #3         |  13%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #3         |  13%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #3         |  14%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #4         |  14%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #4         |  14%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #4         |  15%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #5         |  15%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #5         |  16%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #5         |  16%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #6         |  16%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #6         |  17%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #7         |  17%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #7         |  18%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #7         |  18%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #8         |  18%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #8         |  19%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #8         |  19%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #9         |  19%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #9         |  19%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ##         |  20%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ##         |  21%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ##         |  21%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ##1        |  21%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ##1        |  22%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ##2        |  22%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ##2        |  23%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ##3        |  23%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ##3        |  24%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ##3        |  24%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ##4        |  24%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ##4        |  25%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ##4        |  25%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ##5        |  25%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ##6        |  26%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ##6        |  27%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ##7        |  27%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ##7        |  28%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ##7        |  28%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ##8        |  28%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ##8        |  28%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ##8        |  29%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ##9        |  29%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ##9        |  30%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ###        |  31%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ###1       |  31%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ###1       |  32%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ###2       |  32%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ###2       |  33%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ###3       |  34%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ###4       |  34%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ###4       |  35%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ###5       |  35%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ###5       |  36%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ###6       |  37%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ###7       |  37%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ###7       |  38%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ###8       |  38%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ###8       |  39%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ###9       |  40%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ####       |  40%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ####       |  41%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ####1      |  41%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ####1      |  42%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ####2      |  42%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ####2      |  43%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ####3      |  43%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ####4      |  44%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ####4      |  45%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ####5      |  46%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ####6      |  46%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ####6      |  47%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ####7      |  48%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ####8      |  48%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ####8      |  49%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ####9      |  49%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #####      |  50%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #####      |  51%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #####1     |  51%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #####1     |  52%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #####2     |  52%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #####3     |  53%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #####3     |  54%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #####4     |  54%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #####4     |  55%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #####5     |  55%
#
#
# Note: you may need to restart the kernel to use updated packages.
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #####6     |  56%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #####6     |  57%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #####7     |  57%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #####7     |  58%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #####8     |  58%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #####9     |  59%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #####9     |  60%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ######     |  60%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ######     |  61%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ######1    |  61%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ######2    |  62%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ######2    |  63%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ######3    |  63%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ######3    |  64%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ######4    |  64%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ######5    |  65%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ######5    |  66%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ######6    |  66%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ######6    |  67%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ######7    |  67%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ######8    |  68%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ######8    |  69%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ######9    |  69%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ######9    |  70%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #######    |  70%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #######1   |  71%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #######1   |  72%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #######2   |  72%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #######2   |  73%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #######3   |  73%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #######3   |  74%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #######4   |  75%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #######5   |  75%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #######5   |  76%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #######6   |  76%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #######7   |  77%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #######7   |  78%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #######8   |  78%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #######8   |  79%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #######9   |  79%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #######9   |  80%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ########   |  80%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ########   |  81%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ########1  |  81%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ########1  |  82%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ########2  |  82%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ########2  |  83%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ########3  |  84%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ########4  |  84%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ########4  |  85%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ########5  |  85%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ########6  |  86%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ########6  |  87%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ########7  |  87%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ########7  |  88%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ########8  |  88%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ########9  |  89%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ########9  |  89%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ########9  |  90%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ########9  |  90%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #########  |  90%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #########  |  91%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #########  |  91%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #########2 |  92%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #########2 |  92%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #########2 |  93%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #########2 |  93%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #########3 |  93%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #########3 |  94%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #########3 |  94%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #########4 |  94%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #########4 |  94%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #########4 |  95%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #########5 |  95%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #########5 |  95%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #########5 |  96%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #########5 |  96%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #########6 |  96%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #########6 |  97%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #########6 |  97%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #########7 |  97%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #########7 |  98%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #########8 |  98%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #########9 | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | #########9 | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 5.2 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done

# %%
#14.3 Visualizing a Decision Tree Model

# Load libraries
import pydotplus
from sklearn.tree import DecisionTreeClassifier
from sklearn import datasets
from IPython.display import Image
from sklearn import tree
# Load data
iris=datasets.load_iris()
features=iris.data
target=iris.target
# Create decision tree classifier object
decisiontree=DecisionTreeClassifier(random_state=0)
# Train model
model=decisiontree.fit(features,target)
# Create DOT data
dot_data=tree.export_graphviz(decisiontree,
out_file=None,
feature_names=iris.feature_names,
class_names=iris.target_names)
# Draw graph
graph=pydotplus.graph_from_dot_data(dot_data)
# Show graph
Image(graph.create_png())

# %%
#Create PDF
graph.write_pdf("iris.pdf")
# Out:
# True

# %%
# Create PNG
graph.write_png("iris.png")
# Out:
# True

# %%
#14.4 Training a Random ForestClassiﬁer

# Load libraries
from sklearn.ensemble import RandomForestClassifier
from sklearn import datasets
# Load data
iris=datasets.load_iris()
features=iris.data
target=iris.target
# Create random forest classifier object
randomforest=RandomForestClassifier(random_state=0,n_jobs=-1)
# Train model
model=randomforest.fit(features,target)
# Make new observation
observation=[[5,4,3,2]]
# Predict observation's class
model.predict(observation)
# Out:
# array([1])

# %%
# Create random forest classifier object using entropy
randomforest_entropy=RandomForestClassifier(
criterion="entropy",random_state=0)
# Train model
model_entropy=randomforest_entropy.fit(features,target)

# %%
#14.5 Training a Random Forest Regressor

# Load libraries
from sklearn.ensemble import RandomForestRegressor
from sklearn import datasets
# Load data with only two features
boston=datasets.load_boston()
features=boston.data[:,0:2]
target=boston.target
# Create random forest classifier object
randomforest=RandomForestRegressor(random_state=0,n_jobs=-1)
# Train model
model=randomforest.fit(features,target)
# Out:
# C:\Users\cduy5\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function load_boston is deprecated; `load_boston` is deprecated in 1.0 and will be removed in 1.2.
#
#     The Boston housing prices dataset has an ethical problem. You can refer to
#     the documentation of this function for further details.
#
#     The scikit-learn maintainers therefore strongly discourage the use of this
#     dataset unless the purpose of the code is to study and educate about
#     ethical issues in data science and machine learning.
#
#     In this special case, you can fetch the dataset from the original
#     source::
#
#         import pandas as pd
#         import numpy as np
#
#
#         data_url = "http://lib.stat.cmu.edu/datasets/boston"
#         raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#         data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#         target = raw_df.values[1::2, 2]
#
#     Alternative datasets include the California housing dataset (i.e.
#     :func:`~sklearn.datasets.fetch_california_housing`) and the Ames housing
#     dataset. You can load the datasets as follows::
#
#         from sklearn.datasets import fetch_california_housing
#         housing = fetch_california_housing()
#
#     for the California housing dataset and::
#
#         from sklearn.datasets import fetch_openml
#         housing = fetch_openml(name="house_prices", as_frame=True)
#
#     for the Ames housing dataset.
#
#   warnings.warn(msg, category=FutureWarning)

# %%
#14.6 Identifying Important Features in Random Forests

# Load libraries
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn import datasets
# Load data
iris=datasets.load_iris()
features=iris.data
target=iris.target
# Create random forest classifier object
randomforest=RandomForestClassifier(random_state=0,n_jobs=-1)
# Train model
model=randomforest.fit(features,target)
# Calculate feature importances
importances=model.feature_importances_
# Sort feature importances in descending order
indices=np.argsort(importances)[::-1]
names=[iris.feature_names[i] for i in indices]
# Create plot
plt.figure()
# Create plot title
plt.title("Feature Importance")
# Add bars
plt.bar(range(features.shape[1]),importances[indices])
# Add feature names as x-axis labels
plt.xticks(range(features.shape[1]),names,rotation=90)
# Show plot
plt.show()

# %%
# View feature importances
model.feature_importances_
# Out:
# array([0.09090795, 0.02453104, 0.46044474, 0.42411627])

# %%
#14.7 Selecting Important Features in Random Forests

# Load libraries
from sklearn.ensemble import RandomForestClassifier
from sklearn import datasets
from sklearn.feature_selection import SelectFromModel
# Load data
iris=datasets.load_iris()
features=iris.data
target=iris.target
# Create random forest classifier
randomforest=RandomForestClassifier(random_state=0,n_jobs=-1)
# Create object that selects features with importance greater# than or equal to a threshold
selector=SelectFromModel(randomforest,threshold=0.3)
# Feature new feature matrix using selector
features_important=selector.fit_transform(features,target)
# Train random forest using most important featres
model=randomforest.fit(features_important,target)

# %%
#14.8 Handling Imbalanced Classes

# Load libraries
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn import datasets
# Load data
iris=datasets.load_iris()
features=iris.data
target=iris.target
# Make class highly imbalanced by removing first 40 observations
features=features[40:,:]
target=target[40:]
# Create target vector indicating if class 0, otherwise 1
target=np.where((target==0),0,1)
# Create random forest classifier object
randomforest=RandomForestClassifier(
random_state=0,n_jobs=-1,class_weight="balanced")
# Train model
model=randomforest.fit(features,target)

# %%
#14.9 Controlling Tree Size

# Load libraries
from sklearn.tree import DecisionTreeClassifier
from sklearn import datasets
# Load data
iris=datasets.load_iris()
features=iris.data
target=iris.target
# Create decision tree classifier object
decisiontree=DecisionTreeClassifier(random_state=0,
                                    max_depth=None,
                                    min_samples_split=2,
                                    min_samples_leaf=1,
                                    min_weight_fraction_leaf=0,
                                    max_leaf_nodes=None,
                                    min_impurity_decrease=0)
# Train model
model=decisiontree.fit(features,target)

# %%
#14.10 Improving Performance Through Boosting

# Load libraries
from sklearn.ensemble import AdaBoostClassifier
from sklearn import datasets
# Load data
iris=datasets.load_iris()
features=iris.data
target=iris.target
# Create adaboost tree classifier object
adaboost=AdaBoostClassifier(random_state=0)
# Train model
model=adaboost.fit(features,target)

# %%
#14.11 Evaluating Random Forests with Out-of-Bag Errors

# Load libraries
from sklearn.ensemble import RandomForestClassifier
from sklearn import datasets
# Load data
iris=datasets.load_iris()
features=iris.data
target=iris.target
# Create random tree classifier object
randomforest=RandomForestClassifier(
random_state=0,n_estimators=1000,oob_score=True,n_jobs=-1)
# Train model
model=randomforest.fit(features,target)
# View out-of-bag-error
randomforest.oob_score_
# Out:
# 0.9533333333333334
